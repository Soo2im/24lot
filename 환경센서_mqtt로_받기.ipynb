# %% [markdown]
# <a href="https://colab.research.google.com/github/Soo2im/24lot/blob/main/%ED%99%98%EA%B2%BD%EC%84%BC%EC%84%9C_mqtt%EB%A1%9C_%EB%B0%9B%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 1.2 MB/s eta 0:00:00
# ...

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/#")

def on_message(client, userdata, msg):
    print(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1503 {"dust":"9,11","co2":"379","bme680":"25.89,30.79,721319,100981,28.76","time":"2024-04-04 22:21:39", "serial":20403, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"15,16","co2":"398","bme680":"25.15,31.79,914966,100976,29.10","time":"2024-04-04 22:21:39", "serial":24955, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"11,11","co2":"489","bme680":"26.68,28.84,1574896,101023,25.17","time":"2024-04-04 22:21:40", "serial":20396, "ip":"203.255.190.49"}
# connectware/indoor/data/1503 {"dust":"9,11","co2":"379","bme680":"25.89,30.81,721319,100980,28.68","time":"2024-04-04 22:21:40", "serial":20404, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"14,16","co2":"398","bme680":"25.15,31.80,917462,100976,29.10","time":"2024-04-04 22:21:40", "serial":24956, "ip":"203.255.190.49"}
# ...
